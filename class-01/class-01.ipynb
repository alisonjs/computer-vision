# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
imagem = cv.imread("images/praia.jpeg")
imagem = cv.cvtColor(imagem, cv.COLOR_BGR2GRAY)

# %%
plt.imshow(imagem, cmap="gray")

# %%
imagem.shape
# Out:
# (183, 275)

# %%
image = cv.imread("images/px-people.jpeg")
image = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# %%
plt.imshow(image)

# %%
image.shape
# Out:
# (800, 1200, 3)

# %%
image_roi = image[90:200, 1000:1200]

# %%
plt.imshow(image_roi)

# %%
cv.imwrite("images/image_roi.png", image_roi)
# Out:
# True

# %%
image_roi_bgr = cv.cvtColor(image_roi, cv.COLOR_RGB2BGR)

# %%
cv.imwrite("images/image_roi.png", image_roi)
# Out:
# True

# %%
image = cv.imread("images/1364-img0102.png")

# %%
plt.imshow(cv.cvtColor(image, cv.COLOR_BGR2RGB))

# %%
roi = [236, 380, 530, 670]

# %%
image_roi = image[236:380, 530:670]
plt.imshow(cv.cvtColor(image_roi, cv.COLOR_BGR2RGB))

# %%
image_roi_gray = cv.cvtColor(image_roi, cv.COLOR_BGR2GRAY)
plt.imshow(image_roi_gray, cmap='gray')

# %%
roi_rgb = cv.cvtColor(image_roi_gray, cv.COLOR_GRAY2RGB)

# %%
image_rgb = cv.cvtColor(image, cv.COLOR_BGR2RGB)
plt.imshow(image_rgb)

# %%
image_rgb[236:380, 530:670]=roi_rgb
plt.imshow(image_rgb)
